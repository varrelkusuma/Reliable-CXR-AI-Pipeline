# %%
import pandas as pd
import requests

# %% [markdown]
# # Open-i Dataset

# %% [markdown]
# ## Batch 1

# %%
# Loading pre-processed CSV
df = pd.read_csv('indiana_list.csv', header=None)

# Extract relevant terms as plain text
terms = df.iloc[:, 0].dropna().astype(str).tolist()
term_block = "\n".join(terms[:119])

# %% [markdown]
# ### gpt-oss:20b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group terms that are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. Do not invent or add new terms.
4. Output format:

Final Group
1,"canonical_label":"<term>","members":["<term1>","<term2>",...]

Deleted Term
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_response_gpt = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "gpt-oss:20b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_response_gpt.json()["message"]["content"])
# Out:
# Final Group
# 1,"canonical_label":"Cardiomegaly","members":["Cardiomegaly"]
# 2,"canonical_label":"Aorta","members":["Aorta","Aorta, Thoracic"]
# 3,"canonical_label":"Pulmonary Emphysema","members":["Pulmonary Emphysema","Bullous Emphysema","Emphysema"]
# 4,"canonical_label":"Opacity","members":["Opacity","Density","Infiltrate"]
# 5,"canonical_label":"Pulmonary Fibrosis","members":["Pulmonary Fibrosis","Fibrosis"]
# 6,"canonical_label":"Granuloma","members":["Granuloma","Calcified Granuloma"]
# 7,"canonical_label":"Heart","members":["Heart","Cardiac Shadow","Heart Atria","Heart Ventricles"]
# 8,"canonical_label":"Pleural Effusion","members":["Pleural Effusion"]
# 9,"canonical_label":"Pneumothorax","members":["Pneumothorax","Hydropneumothorax","Hemopneumothorax"]
# 10,"canonical_label":"Pulmonary Edema","members":["Pulmonary Edema","Pulmonary Congestion"]
# 11,"canonical_label":"Thoracic Vertebrae","members":["Thoracic Vertebrae","Thoracic vertebrae"]
#
# Deleted Term
# 1,"Abdomen"
# ...

# %% [markdown]
# ### qwen3:32b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group terms that are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. Do not invent or add new terms.
4. Output format:

Final Group
1,"canonical_label":"<term>","members":["<term1>","<term2>",...]

Deleted Term
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_response_qwen = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "qwen3:32b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_response_qwen.json()["message"]["content"])
# Out:
# Final Group
# 1,"canonical_label":"Cardiomegaly","members":["Cardiomegaly","Cardiac Shadow","Heart Failure"]
# 2,"canonical_label":"Pulmonary Artery","members":["Pulmonary Artery","Aorta, Thoracic","Aorta"]
# 3,"canonical_label":"Chronic Obstructive Pulmonary Disease (COPD)","members":["Pulmonary Disease, Chronic Obstructive","Bullous Emphysema","Pulmonary Emphysema","Lung, Hyperlucent","Airspace Disease","Emphysema"]
# 4,"canonical_label":"Opacity/Density Abnormality","members":["Opacity","Density"]
# 5,"canonical_label":"Pulmonary Fibrosis","members":["Pulmonary Fibrosis","Fibrosis","Cicatrix"]
# 6,"canonical_label":"Pleural Effusion","members":["Pleural Effusion","Costophrenic Angle"]
# 7,"canonical_label":"Pneumothorax","members":["Pneumothorax","Hydropneumothorax","Hemopneumothorax"]
# 8,"canonical_label":"Pulmonary Consolidation/Infiltrate","members":["Consolidation","Infiltrate","Pneumonia"]
# ...

# %% [markdown]
# ### deepseek-r1:32b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group terms that are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. Do not invent or add new terms.
4. Output format:

Final Group
1,"canonical_label":"<term>","members":["<term1>","<term2>",...]

Deleted Term
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_response_deepseek = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "deepseek-r1:32b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_response_deepseek.json()["message"]["content"])
# Out:
# Here is the organized grouping of chest X-ray findings and identification of unrelated terms:
#
# ### Grouped Terms
#
# 1. **Cicatrix (Scarring)**
#    - Members: Cicatrix, Scarring, Granulation Tissue
#
# 2. **Lung Pathology**
#    - Members: Lung, Lungs
#
# 3. **Pulmonary Atelectasis**
#    - Members: Pulmonary Atelectasis, Atelectasis, Volume Loss, Lung Collapse
#
# 4. **Hyperlucency in Lungs**
#    - Members: Lung, Hyperlucent, Hyperlucency
#
# 5. **Pulmonary Edema and Congestion**
#    - Members: Pulmonary Edema, Edema, Congestion, Pulmonary Congestion
#
# 6. **Consolidation (Solid Opacity)**
#    - Members: Consolidation, Solid Opacity
#
# 7. **Pleural Effusion**
#    - Members: Pleural Effusion, Hydropneumothorax, Effusion
#
# 8. **Bone Diseases, Metabolic**
#    - Members: Bone Diseases, Metabolic, Metabolic Bone Disease
#
# 9. **Lymph Nodes**
#    - Members: Lymph Nodes, Lymph nodes
#
# 10. **Spinal Deformities**
# ...

# %% [markdown]
# ## Batch 2

# %%
# Loading pre-processed CSV
df = pd.read_csv('indiana_list_batch2.csv', header=None, delimiter='\t')

# Extract relevant terms as plain text
terms = df.iloc[:, 0].dropna().astype(str).tolist()
term_block = "\n".join(terms[:119])

# %% [markdown]
# ### gpt-oss:20b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group terms that are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. Do not invent or add new terms.
4. Output format:

Final Group
1,"canonical_label":"<term>","members":["<term1>","<term2>",...]

Deleted Term
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_second_response_gpt = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "gpt-oss:20b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_second_response_gpt.json()["message"]["content"])
# Out:
# **Final Group**
# 1,"canonical_label":"Infiltrate","members":["Airspace Disease","Consolidation","Infiltrate","Opacity"]
# 2,"canonical_label":"Subcutaneous Emphysema","members":["Subcutaneous Emphysema","Subcutaneous  Emphysema"]
#
# **Deleted Term**
# 1,"Bone and Bones"
# 2,"Calcinosis"
# 3,"Expansile Bone Lesions"
# 4,"Fractures, Bone"
# 5,"Bone Diseases, Metabolic"
# 6,"Catheters, Indwelling"
# 7,"Blood Vessels"
# 8,"Adipose Tissue"
# 9,"Nipple Shadow"
# 10,"Colonic Interposition"
# 11,"Cervical Vertebrae"
# 12,"Lumbar Vertebrae"
# 13,"Thoracic Vertebrae"
# 14,"Spondylosis"
# 15,"Osteophyte"
# 16,"Sclerosis"
# 17,"Hyperostosis, Diffuse Idiopathic Skeletal"
# 18,"Breast Implants"
# 19,"Mastectomy"
# 20,"Epicardial Fat"
# 21,"Thickening"
# 22,"Markings"
# 23,"Deformity"
# 24,"Shift"
# 25,"Tube, Inserted"
# 26,"Costophrenic Angle"
# 27,"Lucency"
# 28,"Blister"
# 29,"Trachea"
# 30,"Trachea, Carina"
# 31,"Pleura"

# %% [markdown]
# ### qwen3:32b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group terms that are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. Do not invent or add new terms.
4. Output format:

Final Group
1,"canonical_label":"<term>","members":["<term1>","<term2>",...]

Deleted Term
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_second_response_qwen = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "qwen3:32b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_second_response_qwen.json()["message"]["content"])
# Out:
# Final Group
# 1,"canonical_label":"Cardiomegaly","members":["Cardiomegaly"]
# 2,"canonical_label":"Pulmonary Artery","members":["Pulmonary Artery","Hypertension, Pulmonary"]
# 3,"canonical_label":"Cicatrix","members":["Cicatrix","Granuloma","Granulomatous Disease"]
# 4,"canonical_label":"Chronic Obstructive Pulmonary Disease","members":["Pulmonary Disease, Chronic Obstructive","Lung, Hyperlucent","Volume Loss"]
# 5,"canonical_label":"Osteophyte","members":["Osteophyte","Spondylosis","Hyperostosis, Diffuse Idiopathic Skeletal"]
# 6,"canonical_label":"Thickening","members":["Thickening"]
# 7,"canonical_label":"Lung Opacification","members":["Airspace Disease","Consolidation","Infiltrate","Opacity","Lucency","Pneumonia","Pneumonectomy"]
# 8,"canonical_label":"Spinal Deformity","members":["Thoracic Vertebrae","Lumbar Vertebrae","Cervical Vertebrae","Kyphosis","Scoliosis","Deformity"]
# 9,"canonical_label":"Arthritis","members":["Arthritis"]
# ...

# %% [markdown]
# ### deepseek-r1:32b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group terms that are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. Do not invent or add new terms.
4. Output format:

Final Group
1,"canonical_label":"<term>","members":["<term1>","<term2>",...]

Deleted Term
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_second_response_deepseek = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "deepseek-r1:32b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_second_response_deepseek.json()["message"]["content"])
# Out:
# ### Final Group
# 1,"canonical_label":"Pulmonary Emphysema","members":["Pulmonary Emphysema","Pulmonary Disease, Chronic Obstructive"]
# 2,"canonical_label":"Pulmonary Fibrosis","members":["Pulmonary Fibrosis","Lung Diseases, Interstitial"]
# 3,"canonical_label":"Granuloma","members":["Granuloma","Granulomatous Disease"]
# 4,"canonical_label":"Pleural Effusion","members":["Pleural Effusion","Pericardial Effusion"]
# 5,"canonical_label":"Fractures, Bone","members":["Fractures, Bone","Expansile Bone Lesions","Osteophyte","Bone Diseases, Metabolic","Calcinosis","Hypertension, Pulmonary"]
# 6,"canonical_label":"Mass","members":["Mass","Nodule","Cyst"]
#
# ### Deleted Term
# 1,"Breast Implants"
# 2,"Mastectomy"
# 3,"Adipose Tissue"
# 4,"Heart Failure"
# 5,"Heart Atria"
# 6,"Heart Ventricles"
# 7,"Thorax"

# %% [markdown]
# ## Batch 3

# %%
# Loading pre-processed CSV
df = pd.read_csv('indiana_list_batch3.csv', header=None, delimiter='\t')

# Extract relevant terms as plain text
terms = df.iloc[:, 0].dropna().astype(str).tolist()
term_block = "\n".join(terms[:119])

# %% [markdown]
# ### gpt-oss:20b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group terms that are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. Do not invent or add new terms.
4. Output format:

Final Group
1,"canonical_label":"<term>","members":["<term1>","<term2>",...]

Deleted Term
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_third_response_gpt = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "gpt-oss:20b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_third_response_gpt.json()["message"]["content"])
# Out:
# **Final Group**
#
# 1,"canonical_label":"Cardiomegaly","members":["Cardiomegaly"]
# 2,"canonical_label":"Heart Failure","members":["Heart Failure"]
# 3,"canonical_label":"Aortic Aneurysm","members":["Aortic Aneurysm"]
# 4,"canonical_label":"Aorta","members":["Aorta"]
# 5,"canonical_label":"Pulmonary Artery","members":["Pulmonary Artery"]
# 6,"canonical_label":"Chronic Obstructive Pulmonary Disease (COPD)","members":["Pulmonary Disease, Chronic Obstructive","Pulmonary Emphysema"]
# 7,"canonical_label":"Interstitial Lung Disease","members":["Lung Diseases, Interstitial","Pulmonary Fibrosis","Cystic Fibrosis","Sarcoidosis","Tuberculosis","Bronchiectasis"]
# 8,"canonical_label":"Pleural Effusion Group","members":["Pleural Effusion","Pericardial Effusion","Hemothorax"]
# 9,"canonical_label":"Pneumonia","members":["Pneumonia"]
# 10,"canonical_label":"Pneumothorax","members":["Pneumothorax"]
# 11,"canonical_label":"Mass","members":["Mass"]
# ...

# %% [markdown]
# ### qwen3:32b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group terms that are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. Do not invent or add new terms.
4. Output format:

Final Group
1,"canonical_label":"<term>","members":["<term1>","<term2>",...]

Deleted Term
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_third_response_qwen = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "qwen3:32b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_third_response_qwen.json()["message"]["content"])
# Out:
# Final Group
# 1,"canonical_label":"Cardiomegaly","members":["Cardiomegaly","Heart Failure","Heart"]
# 2,"canonical_label":"Pulmonary Artery Pathology","members":["Pulmonary Artery","Hypertension, Pulmonary","Aortic Aneurysm","Aorta","Atherosclerosis"]
# 3,"canonical_label":"Chronic Obstructive Pulmonary Disease","members":["Pulmonary Disease, Chronic Obstructive","Pulmonary Emphysema","Lung, Hyperlucent","Volume Loss"]
# 4,"canonical_label":"Pulmonary Fibrosis","members":["Lung Diseases, Interstitial","Pulmonary Fibrosis","Pulmonary Fibrosis"]
# 5,"canonical_label":"Pleural Abnormalities","members":["Pleural Effusion","Pleura","Thickening","Costophrenic Angle","Diaphragm","Diaphragmatic Eventration"]
# 6,"canonical_label":"Pneumothorax and Air Leak","members":["Pneumothorax","Pneumoperitoneum","Subcutaneous Emphysema"]
# 7,"canonical_label":"Diaphragmatic and Hiatal Hernia","members":["Hernia, Hiatal","Hernia, Diaphragmatic","Colonic Interposition"]
# ...

# %% [markdown]
# ### deepseek-r1:32b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group terms that are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. Do not invent or add new terms.
4. Output format:

Final Group
1,"canonical_label":"<term>","members":["<term1>","<term2>",...]

Deleted Term
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_third_response_deepseek = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "deepseek-r1:32b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_third_response_deepseek.json()["message"]["content"])
# Out:
# ### Final Group
#
# 1. **"canonical_label":"Cardiomegaly","members":["Cardiomegaly"]**
#
# 2. **"canonical_label":"Pulmonary Artery Hypertension","members":["Hypertension, Pulmonary", "Atherosclerosis"]**
#
# 3. **"canonical_label":"Chronic Obstructive Pulmonary Disease","members":["Pulmonary Disease, Chronic Obstructive"]**
#
# 4. **"canonical_label":"Lung Fibrosis","members":["Pulmonary Fibrosis"]**
#
# 5. **"canonical_label":"COPD","members":["Pulmonary Disease, Chronic Obstructive", "Emphysema"]**
#
# 6. **"canonical_label":"Interstitial Lung Diseases","members":["Lung Diseases, Interstitial"]**
#
# 7. **"canonical_label":"Atelectasis","members":["Pulmonary Atelectasis"]**
#
# 8. **"canonical_label":"Pleural Effusion","members":["Pleural Effusion", "Pericardial Effusion"]**
#
# 9. **"canonical_label":"Thoracic Vertebrae Abnormalities","members":["Thoracic Vertebrae", "Kyphosis", "Scoliosis"]**
#
# ...

# %% [markdown]
# # Try Grouping to CheXpert

# %% [markdown]
# ## Grouping the Original List

# %%
# Loading pre-processed CSV
df = pd.read_csv('indiana_list.csv', header=None)

# Extract relevant terms as plain text
terms = df.iloc[:, 0].dropna().astype(str).tolist()
term_block = "\n".join(terms[:119])

# %% [markdown]
# ### gpt-oss:20b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group those terms to these groups: Enlarged Cardiomediastinum, Cardiomegaly, Lung Opacity, Lung Lesion, Edema, Consolidation, Atelectasis, Pneumothorax, Pleural Effusion, Pleural Other, Fracture, Support Devices, and Pneumonia if they are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. If a term is unrelated or not clinically equivalent to the groups, exclude it and list it separately.
4. Do not invent or add new terms.
5. Output format:

Groupings
1,"Enlarged Cardiomediastinum","members":["<term1>","<term2>",...]

Unrelated Term (not clinically equivalent to the groups)
1,"<term>"
2,"<term>"

Deleted Term (not related to chest pathology or indication)
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_response_gpt = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "gpt-oss:20b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_response_gpt.json()["message"]["content"])
# Out:
# **Enlarged Cardiomediastinum**
# Pulmonary Artery, Aorta, Thoracic, Aorta, Aortic Aneurysm
#
# **Cardiomegaly**
# Cardiomegaly, Cardiac Shadow
#
# **Lung Opacity**
# Opacity, Density, Lucency, Infiltrate, Airspace Disease, Thickening, Cavitation
#
# **Lung Lesion**
# Bullous Emphysema, Cicatrix, Pulmonary Fibrosis, Calcified Granuloma, Granulomatous Disease, Emphysema, Lung Diseases, Interstitial, Nodule, Mass, Foreign Bodies, Cysts, Granuloma, Blister, Bronchiectasis, Cystic Fibrosis, Fibrosis, Tuberculosis, Sarcoidosis
#
# **Edema**
# Pulmonary Congestion, Heart Failure, Pulmonary Edema
#
# **Consolidation**
# Consolidation
#
# **Atelectasis**
# Pulmonary Atelectasis, Volume Loss
#
# **Pneumothorax**
# Pneumothorax, Hemopneumothorax, Hydropneumothorax
#
# **Pleural Effusion**
# Pleural Effusion, Hemothorax
#
# **Pleural Other**
# Pericardial Effusion
#
# **Fracture**
# Fractures, Bone
#
# **Support Devices**
# ...

# %% [markdown]
# ### qwen3:32b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group those terms to these groups: Enlarged Cardiomediastinum, Cardiomegaly, Lung Opacity, Lung Lesion, Edema, Consolidation, Atelectasis, Pneumothorax, Pleural Effusion, Pleural Other, Fracture, Support Devices, and Pneumonia if they are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. If a term is unrelated or not clinically equivalent to the groups, exclude it and list it separately.
4. Do not invent or add new terms.
5. Output format:

Groupings
1,"Enlarged Cardiomediastinum","members":["<term1>","<term2>",...]

Unrelated Term (not clinically equivalent to the groups)
1,"<term>"
2,"<term>"

Deleted Term (not related to chest pathology or indication)
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_response_qwen = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "qwen3:32b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_response_qwen.json()["message"]["content"])
# Out:
# Groupings
# 1,"Enlarged Cardiomediastinum","members":["Cardiac Shadow","Aorta","Aorta, Thoracic","Aortic Aneurysm","Epicardial Fat"]
# 2,"Cardiomegaly","members":["Cardiomegaly"]
# 3,"Lung Opacity","members":["Opacity","Density","Markings","Pulmonary Congestion"]
# 4,"Lung Lesion","members":["Cicatrix","Pulmonary Disease, Chronic Obstructive","Pulmonary Fibrosis","Calcified Granuloma","Granulomatous Disease","Pulmonary Emphysema","Bullous Emphysema","Lung, Hyperlucent","Emphysema","Lung Diseases, Interstitial","Fibrosis","Granuloma","Nodule","Mass","Cyst","Cysts","Lucency","Sarcoidosis","Bronchiectasis","Bronchitis","Bronchiolitis"]
# 5,"Edema","members":["Heart Failure","Pulmonary Congestion","Pulmonary Edema","Pericardial Effusion"]
# 6,"Consolidation","members":["Airspace Disease","Consolidation","Infiltrate"]
# 7,"Atelectasis","members":["Pulmonary Atelectasis","Volume Loss"]
# ...

# %% [markdown]
# ### deepseek-r1:32b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group those terms to these groups: Enlarged Cardiomediastinum, Cardiomegaly, Lung Opacity, Lung Lesion, Edema, Consolidation, Atelectasis, Pneumothorax, Pleural Effusion, Pleural Other, Fracture, Support Devices, and Pneumonia if they are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. If a term is unrelated or not clinically equivalent to the groups, exclude it and list it separately.
4. Do not invent or add new terms.
5. Output format:

Groupings
1,"Enlarged Cardiomediastinum","members":["<term1>","<term2>",...]

Unrelated Term (not clinically equivalent to the groups)
1,"<term>"
2,"<term>"

Deleted Term (not related to chest pathology or indication)
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_response_deepseek = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "deepseek-r1:32b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_response_deepseek.json()["message"]["content"])
# Out:
# ### Groupings:
#
# 1. **Enlarged Cardiomediastinum**:
#    - Aorta
#    - Aorta, Thoracic
#    - Cardiac Shadow
#
# 2. **Cardiomegaly**:
#    - Cardiomegaly
#
# 3. **Lung Opacity**:
#    - Airspace Disease
#    - Consolidation
#    - Density
#    - Infiltrate
#
# 4. **Lung Lesion**:
#    - Bullous Emphysema
#    - Calcified Granuloma
#    - Cystic Fibrosis
#    - Fibrosis
#    - Granuloma
#    - Granulomatous Disease
#    - Mass
#    - Nodule
#    - Pulmonary Atelectasis
#    - Pulmonary Fibrosis
#    - Pulmonary Emphysema
#    - Sarcoidosis
#    - Tuberculosis
#
# 5. **Edema**:
#    - Pulmonary Edema
#    - Pericardial Effusion
#
# 6. **Consolidation**:
#    - Consolidation
#
# 7. **Atelectasis**:
#    - Pulmonary Atelectasis
#
# 8. **Pneumothorax**:
#    - Pneumothorax
#    - Hydropneumothorax
#
# 9. **Pleural Effusion**:
#    - Pleural Effusion
#
# 10. **Pleural Other**:
#     - Thickening (pleural thickening)
#     - Subcutaneous Emphysema
#
# 11. **Fracture**:
# ...

# %% [markdown]
# ## Grouping the Filtered List

# %%
# Loading pre-processed CSV
df = pd.read_csv('indiana_list_final.csv', header=None, delimiter='\t')

# Extract relevant terms as plain text
terms = df.iloc[:, 0].dropna().astype(str).tolist()
term_block = "\n".join(terms[:119])

# %% [markdown]
# ### gpt-oss:20b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group those terms to these groups: Enlarged Cardiomediastinum, Cardiomegaly, Lung Opacity, Lung Lesion, Edema, Consolidation, Atelectasis, Pneumothorax, Pleural Effusion, Pleural Other, Fracture, Support Devices, and Pneumonia if they are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. If a term is unrelated or not clinically equivalent to the groups, exclude it and list it separately.
4. Do not invent or add new terms.
5. Output format:

Groupings
1,"Enlarged Cardiomediastinum","members":["<term1>","<term2>",...]

Unrelated Term (not clinically equivalent to the groups)
1,"<term>"
2,"<term>"

Deleted Term (not related to chest pathology or indication)
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_second_response_gpt = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "gpt-oss:20b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_second_response_gpt.json()["message"]["content"])
# Out:
# Groupings
# 1,"Enlarged Cardiomediastinum","members":["Aortic Aneurysm"]
# 2,"Cardiomegaly","members":["Cardiomegaly"]
# 3,"Lung Opacity","members":["Mass","Opacity","Pulmonary Fibrosis"]
# 4,"Lung Lesion","members":["Granuloma","Cavitation"]
# 5,"Edema","members":["Pulmonary Edema"]
# 6,"Consolidation","members":[]
# 7,"Atelectasis","members":["Pulmonary Atelectasis","Volume Loss","Shift"]
# 8,"Pneumothorax","members":["Pneumothorax"]
# 9,"Pleural Effusion","members":["Pleural Effusion","Hemothorax"]
# 10,"Pleural Other","members":["Deformity","Subcutaneous Emphysema","Funnel Chest","Pectus Carinatum","Pleura"]
# 11,"Fracture","members":["Fractures, Bone"]
# 12,"Support Devices","members":["Tube, Inserted","Catheters, Indwelling","Pulmonary Artery"]
# 13,"Pneumonia","members":["Pneumonia"]
#
# Unrelated Term (not clinically equivalent to the groups)
# 1,"Cicatrix"
# 2,"Osteophyte"
# 3,"Thickening"
# 4,"Lung"
# 5,"Markings"
# 6,"Lung, Hyperlucent"
# 7,"Diaphragm"
# ...

# %% [markdown]
# ### qwen3:32b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group those terms to these groups: Enlarged Cardiomediastinum, Cardiomegaly, Lung Opacity, Lung Lesion, Edema, Consolidation, Atelectasis, Pneumothorax, Pleural Effusion, Pleural Other, Fracture, Support Devices, and Pneumonia if they are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. If a term is unrelated or not clinically equivalent to the groups, exclude it and list it separately.
4. Do not invent or add new terms.
5. Output format:

Groupings
1,"Enlarged Cardiomediastinum","members":["<term1>","<term2>",...]

Unrelated Term (not clinically equivalent to the groups)
1,"<term>"
2,"<term>"

Deleted Term (not related to chest pathology or indication)
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_second_response_qwen = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "qwen3:32b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_second_response_qwen.json()["message"]["content"])
# Out:
# Groupings
# 1,"Enlarged Cardiomediastinum","members":["Heart Failure","Epicardial Fat"]
# 2,"Cardiomegaly","members":["Cardiomegaly"]
# 3,"Lung Opacity","members":["Opacity","Mass","Cavitation","Granuloma"]
# 4,"Lung Lesion","members":["Cicatrix","Calcinosis","Cystic Fibrosis","Pulmonary Fibrosis"]
# 5,"Edema","members":["Pulmonary Edema"]
# 6,"Consolidation","members":["Consolidation","Pneumonia","Tuberculosis","Sarcoidosis"]
# 7,"Atelectasis","members":["Pulmonary Atelectasis","Volume Loss","Lung, Hyperlucent"]
# 8,"Pneumothorax","members":["Pneumothorax","Subcutaneous Emphysema"]
# 9,"Pleural Effusion","members":["Pleural Effusion","Hemothorax"]
# 10,"Pleural Other","members":["Diaphragm","Costophrenic Angle","Diaphragmatic Eventration","Colonic Interposition","Shift"]
# 11,"Fracture","members":["Fractures, Bone"]
# 12,"Support Devices","members":["Tube, Inserted","Catheters, Indwelling"]
# 13,"Pneumonia","members":["Pneumonia"]
#
# ...

# %% [markdown]
# ### deepseek-r1:32b

# %%
# Construct the prompt
system_prompt = (
    "You are a board-certified radiologist specializing in chest x-ray (CXR) findings."
    "Your task is to group clinically synonymous terms and identify unrelated ones."
)

user_prompt = f"""
Here is a list of terms from a chest x-ray dataset:

{term_block}

Instructions:
1. Group those terms to these groups: Enlarged Cardiomediastinum, Cardiomegaly, Lung Opacity, Lung Lesion, Edema, Consolidation, Atelectasis, Pneumothorax, Pleural Effusion, Pleural Other, Fracture, Support Devices, and Pneumonia if they are clinically equivalent or synonymous.
2. If a term is unrelated to chest pathology or indication, exclude it and list it separately.
3. If a term is unrelated or not clinically equivalent to the groups, exclude it and list it separately.
4. Do not invent or add new terms.
5. Output format:

Groupings
1,"Enlarged Cardiomediastinum","members":["<term1>","<term2>",...]

Unrelated Term (not clinically equivalent to the groups)
1,"<term>"
2,"<term>"

Deleted Term (not related to chest pathology or indication)
1,"<term>"
2,"<term>"
"""

# Send to Ollama
openi_second_response_deepseek = requests.post(
    'http://127.0.0.1:11434/api/chat',
    json={
        "model": "deepseek-r1:32b",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "stream": False,
        "seed": 17,
        "temperature": 0.3,
        "top_p": 0.9,
        "num_predict": 1024
    }
)

# %%
print(openi_second_response_deepseek.json()["message"]["content"])
# Out:
# Here is the organized grouping of terms based on their clinical equivalence and relevance to chest pathology:
#
# ### Groupings
#
# 1. **Enlarged Cardiomediastinum**
#    - Members: Pulmonary Artery, Aorta, Heart Failure, Shift (mediastinal shift)
#
# 2. **Cardiomegaly**
#    - Members: Cardiomegaly, Epicardial Fat, Hypovolemia (indirect effect), Aortic Aneurysm
#
# 3. **Lung Opacity**
#    - Members: Pulmonary Fibrosis, Sclerosis (if affecting lungs), Pneumonia (opacity in early stages)
#
# 4. **Lung Lesion**
#    - Members: Cicatrix (scar tissue), Cavitation, Granuloma, Tuberculosis (active disease)
#
# 5. **Edema**
#    - Members: Pulmonary Edema, Sulcus (pleural sulcus changes)
#
# 6. **Consolidation**
#    - Members: Pneumonia (consolidation phase)
#
# 7. **Atelectasis**
#    - Members: Pulmonary Atelectasis
#
# 8. **Pneumothorax**
#    - Members: Pneumothorax, Subcutaneous Emphysema, Blister (air collection), Lung, Hyperlucent
#
# 9. **Pleural Effusion**
# ...
